# %%
import pandas as pd
import numpy as np
from PIL import Image

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is F880-8E1B
#
#  Directory of C:\Users\abhay.LAPTOP-9V7O8E88.000\OneDrive\Desktop\AI ENGG\Phase 1 (Foundation)\Pandas\Projects\IPL Data Analysis
#
# 07/17/2026  04:42 PM    <DIR>          .
# 07/16/2026  10:03 PM    <DIR>          ..
# 07/17/2026  04:42 PM    <DIR>          .ipynb_checkpoints
# 07/16/2026  10:03 PM        27,019,953 deliveries.csv
# 07/16/2026  11:44 PM            83,632 ipl_data_analysis.ipynb
# 07/16/2026  10:03 PM           225,266 matches.csv
# 07/16/2026  11:08 PM            44,302 ques.png
#                4 File(s)     27,373,153 bytes
#                3 Dir(s)  11,193,970,688 bytes free

# %%
df1 = pd.read_csv("deliveries.csv")
df2 = pd.read_csv("matches.csv")

# %%
df1
# Out:
#         match_id  inning           batting_team                 bowling_team  \
# 0         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 1         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 2         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 3         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# 4         335982       1  Kolkata Knight Riders  Royal Challengers Bangalore
# ...          ...     ...                    ...                          ...
# 260915   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260916   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260917   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260918   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
# 260919   1426312       2  Kolkata Knight Riders          Sunrisers Hyderabad
#
# ...

# %%
df2
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
df1.shape
# Out:
# (260920, 17)

# %%
df2.shape
# Out:
# (1095, 20)

# %%
df2.shape[0]
# Out:
# 1095

# %%
df2.head(2)
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
#
#                    team2                  toss_winner toss_decision  \
# 0  Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1    Chennai Super Kings          Chennai Super Kings           bat
#
#                   winner result  result_margin  target_runs  target_overs  \
# 0  Kolkata Knight Riders   runs          140.0        223.0          20.0
# 1    Chennai Super Kings   runs           33.0        241.0          20.0
#
#   super_over method    umpire1      umpire2
# 0          N    NaN  Asad Rauf  RE Koertzen
# ...

# %%
df2["winner"].value_counts()
# Out:
# winner
# Mumbai Indians                 144
# Chennai Super Kings            138
# Kolkata Knight Riders          131
# Royal Challengers Bangalore    116
# Rajasthan Royals               112
# Kings XI Punjab                 88
# Sunrisers Hyderabad             88
# Delhi Daredevils                67
# Delhi Capitals                  48
# Deccan Chargers                 29
# Gujarat Titans                  28
# Punjab Kings                    24
# Lucknow Super Giants            24
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Royal Challengers Bengaluru      7
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: count, dtype: int64

# %%
df2["winner"].value_counts().head(1)
# Out:
# winner
# Mumbai Indians    144
# Name: count, dtype: int64

# %%
df1.head(1)
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball      batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1  SC Ganguly  P Kumar  BB McCullum             0           1
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# 0           1     legbyes          0              NaN            NaN     NaN

# %%
runs = df1.groupby("batter")["batsman_runs"].sum()

# %%
print(runs.sort_values(ascending=False).head(10))
# Out:
# batter
# V Kohli           8014
# S Dhawan          6769
# RG Sharma         6630
# DA Warner         6567
# SK Raina          5536
# MS Dhoni          5243
# AB de Villiers    5181
# CH Gayle          4997
# RV Uthappa        4954
# KD Karthik        4843
# Name: batsman_runs, dtype: int64

# %%
wickets = df1[df1["player_dismissed"].notna()]
wickets = wickets.groupby("bowler")["player_dismissed"].count()
print(wickets.sort_values(ascending=False).head(10))
# Out:
# bowler
# YS Chahal     213
# DJ Bravo      207
# PP Chawla     201
# SP Narine     200
# R Ashwin      198
# B Kumar       195
# SL Malinga    188
# A Mishra      183
# JJ Bumrah     182
# RA Jadeja     169
# Name: player_dismissed, dtype: int64

# %%
wickets = df1.groupby("bowler")["is_wicket"].sum()
print(wickets.sort_values(ascending=False).head(10))
# Out:
# bowler
# YS Chahal     213
# DJ Bravo      207
# PP Chawla     201
# SP Narine     200
# R Ashwin      198
# B Kumar       195
# SL Malinga    188
# A Mishra      183
# JJ Bumrah     182
# RA Jadeja     169
# Name: is_wicket, dtype: int64

# %%
df2.head(1)
df2.head(10)
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
# 5  335987  2007/08      Jaipur  2008-04-21     League       SR Watson
# 6  335988  2007/08   Hyderabad  2008-04-22     League        V Sehwag
# 7  335989  2007/08     Chennai  2008-04-23     League       ML Hayden
# 8  335990  2007/08   Hyderabad  2008-04-24     League       YK Pathan
# 9  335991  2007/08  Chandigarh  2008-04-25     League   KC Sangakkara
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# ...

# %%
df2.value_counts("player_of_match").head(10)
# Out:
# player_of_match
# AB de Villiers    25
# CH Gayle          22
# RG Sharma         19
# DA Warner         18
# V Kohli           18
# MS Dhoni          17
# SR Watson         16
# YK Pathan         16
# RA Jadeja         16
# SP Narine         15
# Name: count, dtype: int64

# %%
df2["player_of_match"].value_counts().head(10)
# Out:
# player_of_match
# AB de Villiers    25
# CH Gayle          22
# RG Sharma         19
# DA Warner         18
# V Kohli           18
# MS Dhoni          17
# SR Watson         16
# YK Pathan         16
# RA Jadeja         16
# SP Narine         15
# Name: count, dtype: int64

# %%
toss_match = df2[df2["toss_winner"] == df2["winner"]]
percentage = (len(toss_match) / len(df2)) * 100
print(percentage)
# Out:
# 50.593607305936075

# %%
df2
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
df2.head(2)
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
#
#                    team2                  toss_winner toss_decision  \
# 0  Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1    Chennai Super Kings          Chennai Super Kings           bat
#
#                   winner result  result_margin  target_runs  target_overs  \
# 0  Kolkata Knight Riders   runs          140.0        223.0          20.0
# 1    Chennai Super Kings   runs           33.0        241.0          20.0
#
#   super_over method    umpire1      umpire2
# 0          N    NaN  Asad Rauf  RE Koertzen
# ...

# %%
df2.value_counts("venue").head(10)
# Out:
# venue
# Eden Gardens                                  77
# Wankhede Stadium                              73
# M Chinnaswamy Stadium                         65
# Feroz Shah Kotla                              60
# Rajiv Gandhi International Stadium, Uppal     49
# MA Chidambaram Stadium, Chepauk               48
# Sawai Mansingh Stadium                        47
# Dubai International Cricket Stadium           46
# Wankhede Stadium, Mumbai                      45
# Punjab Cricket Association Stadium, Mohali    35
# Name: count, dtype: int64

# %%
img = Image.open("ques.png")

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=614x779>

# %%
df2.head(2)
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
#
#                    team2                  toss_winner toss_decision  \
# 0  Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1    Chennai Super Kings          Chennai Super Kings           bat
#
#                   winner result  result_margin  target_runs  target_overs  \
# 0  Kolkata Knight Riders   runs          140.0        223.0          20.0
# 1    Chennai Super Kings   runs           33.0        241.0          20.0
#
#   super_over method    umpire1      umpire2
# 0          N    NaN  Asad Rauf  RE Koertzen
# ...

# %%
matches_played = pd.concat([df2["team1"], df2["team2"]]).value_counts()
matches_won = df2["winner"].value_counts()

win_percentage = (matches_won / matches_played) * 100
print(win_percentage.sort_values(ascending=False))
# Out:
# winner
# Rising Pune Supergiant         62.500000
# Gujarat Titans                 62.222222
# Chennai Super Kings            57.983193
# Mumbai Indians                 55.172414
# Lucknow Super Giants           54.545455
# Delhi Capitals                 52.747253
# Kolkata Knight Riders          52.191235
# Rajasthan Royals               50.678733
# Sunrisers Hyderabad            48.351648
# Royal Challengers Bangalore    48.333333
# Royal Challengers Bengaluru    46.666667
# Kings XI Punjab                46.315789
# Gujarat Lions                  43.333333
# Punjab Kings                   42.857143
# Kochi Tuskers Kerala           42.857143
# Delhi Daredevils               41.614907
# Deccan Chargers                38.666667
# Rising Pune Supergiants        35.714286
# Pune Warriors                  26.086957
# Name: count, dtype: float64

# %%
matches_played
# Out:
# Mumbai Indians                 261
# Kolkata Knight Riders          251
# Royal Challengers Bangalore    240
# Chennai Super Kings            238
# Rajasthan Royals               221
# Kings XI Punjab                190
# Sunrisers Hyderabad            182
# Delhi Daredevils               161
# Delhi Capitals                  91
# Deccan Chargers                 75
# Punjab Kings                    56
# Pune Warriors                   46
# Gujarat Titans                  45
# Lucknow Super Giants            44
# Gujarat Lions                   30
# Rising Pune Supergiant          16
# Royal Challengers Bengaluru     15
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=614x779>

# %%
df2.head(1)
# Out:
#        id   season       city        date match_type player_of_match  \
# 0  335982  2007/08  Bangalore  2008-04-18     League     BB McCullum
#
#                    venue                        team1                  team2  \
# 0  M Chinnaswamy Stadium  Royal Challengers Bangalore  Kolkata Knight Riders
#
#                    toss_winner toss_decision                 winner result  \
# 0  Royal Challengers Bangalore         field  Kolkata Knight Riders   runs
#
#    result_margin  target_runs  target_overs super_over method    umpire1  \
# 0          140.0        223.0          20.0          N    NaN  Asad Rauf
#
#        umpire2
# 0  RE Koertzen

# %%
print(df2.groupby("season")["winner"].last())
# Out:
# season
# 2007/08         Rajasthan Royals
# 2009             Deccan Chargers
# 2009/10      Chennai Super Kings
# 2011         Chennai Super Kings
# 2012       Kolkata Knight Riders
# 2013              Mumbai Indians
# 2014       Kolkata Knight Riders
# 2015              Mumbai Indians
# 2016         Sunrisers Hyderabad
# 2017              Mumbai Indians
# 2018         Chennai Super Kings
# 2019              Mumbai Indians
# 2020/21           Mumbai Indians
# 2021         Chennai Super Kings
# 2022              Gujarat Titans
# 2023         Chennai Super Kings
# 2024       Kolkata Knight Riders
# Name: winner, dtype: str

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=614x779>

# %%
df2
# Out:
#            id   season        city        date   match_type  player_of_match  \
# 0      335982  2007/08   Bangalore  2008-04-18       League      BB McCullum
# 1      335983  2007/08  Chandigarh  2008-04-19       League       MEK Hussey
# 2      335984  2007/08       Delhi  2008-04-19       League      MF Maharoof
# 3      335985  2007/08      Mumbai  2008-04-20       League       MV Boucher
# 4      335986  2007/08     Kolkata  2008-04-20       League        DJ Hussey
# ...       ...      ...         ...         ...          ...              ...
# 1090  1426307     2024   Hyderabad  2024-05-19       League  Abhishek Sharma
# 1091  1426309     2024   Ahmedabad  2024-05-21  Qualifier 1         MA Starc
# 1092  1426310     2024   Ahmedabad  2024-05-22   Eliminator         R Ashwin
# 1093  1426311     2024     Chennai  2024-05-24  Qualifier 2    Shahbaz Ahmed
# 1094  1426312     2024     Chennai  2024-05-26        Final         MA Starc
#
# ...

# %%
df1.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# ...

# %%
team_score = df1.groupby(
    ["match_id", "inning", "batting_team"]
)["total_runs"].sum()

print(team_score.sort_values(ascending=False).head(10))
# Out:
# match_id  inning  batting_team
# 1426268   1       Sunrisers Hyderabad            287
# 1422126   1       Sunrisers Hyderabad            277
# 1422134   1       Kolkata Knight Riders          272
# 1426273   1       Sunrisers Hyderabad            266
# 598027    1       Royal Challengers Bangalore    263
# 1426268   2       Royal Challengers Bengaluru    262
# 1426280   2       Punjab Kings                   262
#           1       Kolkata Knight Riders          261
# 1359512   1       Lucknow Super Giants           257
# 1426281   1       Delhi Capitals                 257
# Name: total_runs, dtype: int64

# %%
team_score.sort_values().head(10)
# Out:
# match_id  inning  batting_team
# 829813    2       Royal Challengers Bangalore    2
# 1216493   3       Kings XI Punjab                2
# 1216512   3       Sunrisers Hyderabad            2
#           4       Kolkata Knight Riders          3
# 1216493   4       Delhi Capitals                 3
# 1216517   3       Kings XI Punjab                5
#           4       Mumbai Indians                 5
# 1082625   4       Gujarat Lions                  6
# 829741    4       Rajasthan Royals               6
# 1216547   3       Mumbai Indians                 7
# Name: total_runs, dtype: int64

# %%
sixes = df1[df1["batsman_runs"] == 6 ]

# %%
sixes["batter"].value_counts().head()
# Out:
# batter
# CH Gayle          359
# RG Sharma         281
# V Kohli           273
# AB de Villiers    253
# MS Dhoni          252
# Name: count, dtype: int64

# %%
four = df1[df1["batsman_runs"] == 4 ]
four["batter"].value_counts().head()
# Out:
# batter
# S Dhawan     768
# V Kohli      708
# DA Warner    663
# RG Sharma    599
# SK Raina     506
# Name: count, dtype: int64

# %%
print(df2["season"].value_counts().sort_index())
# Out:
# season
# 2007/08    58
# 2009       57
# 2009/10    60
# 2011       73
# 2012       74
# 2013       76
# 2014       60
# 2015       59
# 2016       60
# 2017       59
# 2018       60
# 2019       60
# 2020/21    60
# 2021       60
# 2022       74
# 2023       74
# 2024       71
# Name: count, dtype: int64

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=614x779>
